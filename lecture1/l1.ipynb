# %% [markdown]
# # lecture 1
# https://youtu.be/Rv6UFGNmNZg?si=hA6KR6VMalDkrV2I

# %% [markdown]
# ## Agenda
# 1. set up the github {Repository}
#     1. setup new environment
#     2. project structure (setup.py)
#     3. requirements.txt
#
# 2. setup and requirements

# %% [markdown]
# ---

# %% [markdown]
# 1. open anaconda prompt > paste cd path > code .
# 2. create virtual environments(to install packages easily):
#     - conda create -p name(venv) python==3.8(version) -y(direct download)
#     - conda activate venv/
#     - conda deactivate
# 3. connect git
#     - first time: go to git global config we get commands
#         - git config --global user.name "name"
#         - git config --global user.mail "@gmail.com"
#     - create new repo and push
#     - now create a new file ".gitignore" -> choose(python) :
#         - this removes uncommited files like(venv ,etc..)
# 4. now create project structure:
#     - src(folder)
#         - "__init__.py" (auto creates if not created)
#     - readme.md
#     - setup.py ('it has #meta data information about project and connects project package and helps in installing requiremnts.txt')
#     - requirements.txt ('include -e .  #auto triggers setup.py')
#
# ---
# ---

# %% [markdown]
# # lecture 2

# %% [markdown]
# ## Agenda
# 1. structure
# 2. Looping
# 3. Exception Handling

# %% [markdown]
# ### notes
# - pkg=>package==folder
#
# - src(pkg)
#     - components (pkg) --> all the modules that we create like data ingestion(reading data) ...
#         - __init__.py
#         - data_ingestion.py (reading data code,train test split...)
#         - data_transformation.py (transformation code-->num to cal , one hot encoding...)
#         - model_trainer.py (matrics , training,push model.pkl to cloud..)
#     - pipeline (pkg) -->
#         - __init__.py
#         - train_pipeline.py (training pipeline that triggers components)
#         - predict_pipeline.py (for prediction of new data)
#     - logger.py (for logging)
#     - exception.py (for exception handling)
#     - utils.py (comman functionalities like(reading ds,saving model we call components here itself))
